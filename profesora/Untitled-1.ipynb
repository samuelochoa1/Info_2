# %%
import dicom2nifti
import nibabel as nib
from nilearn import plotting, image
import pydicom
import numpy as np
from numpy import size
import os
from os import remove , listdir
import nilearn
from nilearn import plotting 
import matplotlib.pyplot as plt
from pydicom.data import get_testdata_file
from pydicom import dcmread 

import dicom2nifti

#Importamos todos las librerias y subcodigos de las libreriamos que vamos a usar para este programa
fpath = get_testdata_file('CT_small.dcm')
ds = dcmread(fpath)
#Leemos los datos de las carpetams DCM , guardandolos en 3 varibales 
datos1 =  pydicom.dcmread(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0001\IMG0001.dcm')
datos2 =  pydicom.dcmread(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0002\IMG_0000_0001.dcm')
datos3 =  pydicom.dcmread(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0003\IMG0001.dcm')
#Creamos la clase que nos va a indicar los ID de los pacientes y ciertos contadores necesarios para posteriores funciones
class obtenerdatos():
    def __init__(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        self.nifti1=0
        self.nifti2=0
        self.nifti3=0
        self.pasiente1es=211
        self.pasiente2es=211
        self.pasiente3es=321
        #Funcion verificar , la cual nos dara informacion de los estudios que contienen los pacientes y si no posee este estudio , agregarlo al paciente indicado
    def Verificar(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        self.pasiente1es=211
        self.pasiente2es=211
        self.pasiente3es=321
        #Definimos el estuido que buscamos
        ESdesc=input("Ingresa el nombre del estuido : ")
        #Se busca en todos los pacientes si el estudio pertenecea estso mismos 
        desc= pydicom.dcmread(r""+ESdesc+"")
        if desc.PatientID == self.ID1 :
            print("Estudio ya registrado en el paciente con ID",self.ID1)  
        elif desc.PatientID == self.ID2 :
            print("Estudio ya registrado en el paciente con ID",self.ID2)
        elif desc.PatientID == self.ID3 :
            print("Estudio ya registrado en el paciente con ID",self.ID3)
        else :
            #si el estudio no pertenece a ningun paciente , se pregunta si se desea agregar y a que pacinete
            x=input("Estudio no registrado , desea agregarlo ?")
            if x == "si":
                donde=input("indique el ID del paciente que desea agregarlo :")
                if donde==self.ID1 :
                    self.datos1.save_as(ESdesc)
                    #Se añade a la lista de estudios de cada paciente un contador de +1 , indicando que se sumo un estudio mas
                    self.pasiente1es=self.pasiente1es+1
                elif donde==self.ID2 :
                    self.datos1.save_as(ESdesc)
                    self.pasiente1es=self.pasiente2es+1
                elif donde==self.ID3 :
                    self.datos1.save_as(ESdesc)
                    self.pasiente1es=self.pasiente3es+1
            else :
                #Si se niega el agregado del estudio , se indica y se devuelve al menu principal
                print("ARCHIVO NO GUARDADO")

        
    #Se define el util de buscar estudios , para encontrar en los pacientes el estudio que se desea encontrar 
    def buscarestudio(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        ESconoci=input("Ingresa el estudio que deseas consultar si pertenece a la base de datos : ")
        conoci= pydicom.dcmread(r''+ESconoci+'')
        #Segun el ID que tenga el estudio se puede buscar este estudio en los pacientes
        if conoci.PatientID == self.ID1 :
            print("Estudio encontrado en el paciente con ID",self.ID1)   
            
        elif conoci.PatientID == self.ID2 :
            print("Estudio encontrado en el paciente con ID",self.ID2)
            
        elif conoci.PatientID == self.ID3 :
            print("Estudio encontrado en el paciente con ID",self.ID3)
        else :
            #Si no se encuentra el estudio , se indica y se devuelve al menu principal
            print("ESTUDIO NO ENCONTRADO EN LA BASE DE DATOS")
            

    #Definimos el util de eliminar estudio , indicando nuevamente el ID del paciente al que le deseamos eliminar
    def eliminarestudio(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        ESelimin=input("Ingresa el ID del paciente al que le deseas eliminar los estudios :")
        if ESelimin == self.ID1 :
            #Se indica el ID , se carga el estudio y se elminia de la carpeta del paciente al que le especificamos
            estuelim=input("Que estudio desea eliminar del paciente con ID"+self.ID2)
            for estu in listdir(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0001'):
                #Se usa try except para evitar que el codigo se rompa , intentando cargar la imagen que ya fue borrada
                try :
                    remove(r""+estuelim+"")
                except FileNotFoundError:
                    pass
        elif ESelimin == self.ID2 :
            estuelim=input("Que estudio desea eliminar del paciente con ID"+self.ID2)
            for estu in listdir(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0002'):
                try :
                    remove(r""+estuelim+"")
                except FileNotFoundError:
                    pass
        elif ESelimin == self.ID3 :
            estuelim=input("Que estudio desea eliminar del paciente con ID"+self.ID3)
            for estu in listdir(r'C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0003'):
                try :
                    remove(r""+estuelim+"")
                except FileNotFoundError:
                    pass

    #Definimos el util de consultar datos , el cual segun el ID que indiquemos sera el paciente al que le queramos cosnultar
    def consultardatos(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        IDpaciente=input("Indique el ID del paciente")
        if IDpaciente == self.ID1 :
            #Segun lo que indique el usuario en el menu sera lo que imprima el programa 
            consul=input("Que desa consultar del pacinete con ID"+IDpaciente+'\n 1°)Fecha'+' \n 2°)Modalidad \n'+' 3°)Descripción'+' \n 4°)Dimensiones imagen '+'\n5°)Cantidad de estudios') 
            if consul == "1" :
                print("El tiempo del estudio es ",datos1.StudyTime)
            elif consul =="2" :
                print("La modalidad del estudio es ",datos1.Modality)
            elif consul == "3" :
                print("La descripcion del estudio es ",datos1.SeriesDescription)
            elif consul == "4" :
                #Usamos la notacion mmXmm para la imagen , multiplicando el tamaño de los pixeles por la cantidad de estos en cada eje 
                Xp=datos1.pixel_array
                Yp=datos1.pixel_array
                print(Xp.shape[0])
                print(Yp.shape[1])
                mm=[int(datos1.PixelSpacing[0]*Xp.shape[0]) , int(datos1.PixelSpacing[1]*Yp.shape[1])]
                print("Las dimensiones de la imagen son ",mm[0],"mm de ancho X ",mm[1],"mm de largo")
            elif consul=="5":
                #Imprimimos la lista de cantidad de estudios si se requiere
                print("El paciente con id "+IDpaciente+'tiene : ',self.pasiente1es,'estudios')

        elif IDpaciente == self.ID2:
            consul=input("Que desa consultar del pacinete con ID",IDpaciente,'\n 1°)Fecha \n 2°)Modalidad \n 3°)Descripción \n 4°)Dimensiones imagen '+'\n5°)Cantidad de estudios') 
            if consul == "1" :
                print("El tiempo del estudio es ",datos2.StudyTime)
            elif consul =="2" :
                print("La modalidad del estudio es ",datos2.Modality)
            elif consul == "3" :
                print("La descripcion del estudio es ",datos2.SeriesDescription)
            elif consul == "4" :
                Xp=datos2.pixel_array
                Yp=datos2.pixel_array
                print(Xp.shape[0])
                print(Yp.shape[1])
                mm=[int(datos2.PixelSpacing[0]*Xp.shape[0]) , int(datos2.PixelSpacing[1]*Yp.shape[1])]
                print("Las dimensiones de la imagen son ",mm[0],"mm de ancho X ",mm[1],"mm de largo")
            elif consul=="5":
                print("El paciente con id "+IDpaciente+'tiene : ',self.pasiente2es,'estudios')
     
        elif IDpaciente == self.ID3:
            consul=input("Que desa consultar del pacinete con ID",IDpaciente,'\n 1°)Fecha \n 2°)Modalidad \n 3°)Descripción \n 4°)Dimensiones imagen '+'\n5°)Cantidad de estudios') 
            if consul == "1" :
                print("El tiempo del estudio es ",datos3.StudyTime)
            elif consul =="2" :
                print("La modalidad del estudio es ",datos3.Modality)
            elif consul == "3" :
                print("La descripcion del estudio es ",datos3.SeriesDescription)
            elif consul == "4" :
                Xp=datos3.pixel_array
                Yp=datos3.pixel_array
                print(Xp.shape[0])
                print(Yp.shape[1])
                mm=[int(datos3.PixelSpacing[0]*Xp.shape[0]) , int(datos3.PixelSpacing[1]*Yp.shape[1])]
                print("Las dimensiones de la imagen son ",mm[0],"mm de ancho X ",mm[1],"mm de largo") 
            elif consul=="5":
                print("El paciente con id "+IDpaciente+'tiene : ',self.pasiente3es,'estudios')
    #Definimos el util de anonimizar estudios , solo se anonimiza el ID y la modalidad del estudio que serian los mas sensibles de los detalles 
    def Anonimizar(self):
        eleanonim = ['PatientID','Modality']
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        idcom=input("Indique el ID del paciente que desea anonimizar su NOMBRE y MODALIDAD :")
        if idcom==self.ID1:
            #Segun el ID se anonimiza el estudio , su ID y modalidad , para luego reguardar el archivo y que este quede anonimizado 
            for i in eleanonim:
                datos1[i].value=None
            datos1.save_as('ANONIMO.dcm')
            print("CAMBIOS REALIZADOS CORRECTAMENTE")
        if idcom==self.ID2:
            for i in eleanonim:
                datos2[i].value=None
            datos2.save_as('ANONIMO.dcm')
            print("CAMBIOS REALIZADOS CORRECTAMENTE")
        if idcom==self.ID3:
            for i in eleanonim:
                datos3[i].value=None
            datos3.save_as('ANONIMO.dcm')
            print("CAMBIOS REALIZADOS CORRECTAMENTE")

    #Se define el util de convertir archivos a NIFTI para facilitar el uso de graficas
    def NIFTI(self):
        self.ID1 =  datos1.PatientID
        self.ID2 =  datos2.PatientID
        self.ID3 =  datos3.PatientID
        self.nifti1=0
        self.nifti2=0
        self.nifti3=0
        #Se le advietrte al usuario sobre que sus estudios seran recodificados en un archivo nifti
        print("ADVERTENCIA , LOS ESTUDIOS SE RECODIFICARAN EN ARCHIVOS NIFTI")
        x=input("Indique el ID del paciente al que quiere imprimir los estudios : "+"\nDIGITE NO PARA CANCELAR RECODIFICACIÓN")
        if x=="NO":
            #Si el usuario considera que la recodificacion no es necesaria , puede cancelarlo
            print("RECODIFICACIÓN CANCELADA")
        if x == self.ID1 :
            if self.nifti1==0:
                #Se usa un contador para evitar que se vuelvan a recodificar los datos , usando un condicional
                self.nifti1=self.nifti1+1
                nifti_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001"    
                dicom_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0001"
                dicom2nifti.convert_directory(dicom_directory,nifti_directory)
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                #Se le pregunta al usaurio por medio de un menu como desea imprimir los estudios 
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
                    
            elif self.nifti1==2:
                #Si se detecta que el usario ya recodifico , se le indica y se le pide nuevamente que indique de que modo desea graficar
                print("DATOS YA RECODIFICADOS")
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_001\1_rm_cerebro_t1.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
                    

        elif x == self.ID2 :
            if self.nifti2==0:
                self.nifti2=self.nifti2+1
                nifti_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002"    
                dicom_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0002"
                dicom2nifti.convert_directory(dicom_directory,nifti_directory)
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
                    
            elif self.nifti2==1:
                print("DATOS YA RECODIFICADOS")
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_002\1_rm_cerebro_flair.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
                    
            

        elif x == self.ID3 :
            if self.nifti3==0:
                self.nifti3=self.nifti3+1
                nifti_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003"    
                dicom_directory = r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\0003"
                dicom2nifti.convert_directory(dicom_directory,nifti_directory)
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
                    
            elif self.nifti3==1:
                print("DATOS YA RECODIFICADOS")
                imprimir=input("De que manera desea imprimir los estudios : "+"\n1°)Plano axial"+"\n2°)Plano axial , sagital y coronal"+"\n3°)Mosaico")
                if imprimir=="1":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='z', title='Plano axial')
                    plt.show()
                    
                elif imprimir=="2":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='ortho', title='Plano axial, sagital y coronal')
                    plt.show()
                
                elif imprimir=="3":
                    img=r"C:\Users\Juan Pablo Jimenez S\Downloads\profesora\nifti_003\301_ct_heart.nii.gz"
                    plotting.plot_anat(img, display_mode='mosaic', title='Mosaico')
                    plt.show()
            
    
#Creamos el menu o interfaz del usuario , con opcion de todos los utiles anteriormente creados
while True :
    x=int(input("indique que desea realizar"+"\n1°Verificar Estudio"+"\n2°Buscar Estudio"+"\n3°Eliminar Estudio"+"\n4°Consultar Datos"+"\n5°Anonimizar Estudio"+"\n6°Graficar"+"\n7°Salir"))
    #Segun la respuesta del usuairo , se usa el util 
    if x==1 :
        clas=obtenerdatos()
        clas.Verificar()
    if x==2 :
        clas=obtenerdatos()
        clas.buscarestudio()
    if x==3 :
        clas=obtenerdatos()
        clas.eliminarestudio()
    if x==4 :
        clas=obtenerdatos()
        clas.consultardatos()
    if x==5 :
        clas=obtenerdatos()
        clas.Anonimizar()
    if x==6 :
        clas=obtenerdatos()
        clas.NIFTI()
    #Despues de terminar el programa , se indica el nuemro 7 para detener el programa
    if x==7:
        break
