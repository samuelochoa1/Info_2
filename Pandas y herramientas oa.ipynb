# %%
import pandas as pd
import numpy as np



s=pd.Series(np.random.randn(5), index=["a","b","c","d","e"])
s
# Out:
# a   -0.441009
# b   -1.032274
# c   -2.470658
# d    1.402362
# e    1.214262
# dtype: float64

# %%
d= {"b":1,"a":0,"c":2}
s1=pd.Series(d,index=["b","c","d","a"])
s1
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
import os
import glob

current= os.getcwd()
file=glob.glob(current+"/*.csv")

# %%
file
# Out:
# ['c:\\Users\\DRA01\\Desktop\\Pandas\\alzheimer.csv']

# %%
alzheimer=pd.read_csv(file[0],sep=";")

# %%
alzheimer
# Out:
#        Group Sexo  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Control    F   87    14    2    27  0.0  1987  0.696  0.883
# 1    Control    F   88    14    2    30  0.0  2004  0.681  0.876
# 2        DCL    F   75    12    3    23  0.5  1678  0.736  1.046
# 3        DCL    F   76    12    2    28  0.5  1738  0.713  1.010
# 4        DCL    F   80    12    3    22  0.5  1698  0.701  1.034
# ..       ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      DCL    F   82    16    1    28  0.5  1693  0.694  1.037
# 369      DCL    F   86    16    1    26  0.5  1688  0.675  1.040
# 370  Control    M   61    13    2    30  0.0  1319  0.801  1.331
# 371  Control    M   63    13    2    30  0.0  1327  0.796  1.323
# 372  Control    M   65    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
alzheimer.size
# Out:
# 3730

# %%
alzheimer.shape
# Out:
# (373, 10)

# %%
alzheimer.columns
# Out:
# Index(['Group', 'Sexo', 'Age', 'Educ', 'SES', 'MMSE', 'CDR', 'eTIV', 'nWBV',
#        'ASF'],
#       dtype='object')

# %%
alzheimer.describe()
# Out:
#               Age        Educ         SES        MMSE         CDR  \
# count  373.000000  373.000000  373.000000  373.000000  373.000000
# mean    77.013405   14.597855    2.495979   27.268097    0.290885
# std      7.640957    2.876339    1.139756    3.811834    0.374557
# min     60.000000    6.000000    1.000000    4.000000    0.000000
# 25%     71.000000   12.000000    2.000000   27.000000    0.000000
# 50%     77.000000   15.000000    2.000000   29.000000    0.000000
# 75%     82.000000   16.000000    3.000000   30.000000    0.500000
# max     98.000000   23.000000    5.000000   30.000000    2.000000
#
#               eTIV        nWBV         ASF
# count   373.000000  373.000000  373.000000
# mean   1490.809651    0.729568    1.195461
# std     175.826615    0.037135    0.138092
# min    1106.000000    0.644000    0.876000
# 25%    1359.000000    0.700000    1.099000
# 50%    1474.000000    0.729000    1.194000
# 75%    1600.000000    0.756000    1.293000
# max    2004.000000    0.837000    1.587000

# %%
alzheimer.loc[0]
# Out:
# Group    Control
# Sexo           F
# Age           87
# Educ          14
# SES            2
# MMSE          27
# CDR          0.0
# eTIV        1987
# nWBV       0.696
# ASF        0.883
# Name: 0, dtype: object

# %%
alzheimer_copy=alzheimer_copy.reset_index()
alzheimer_copy
# Out:
#      index  level_0    Group  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0        0        0  Control    14    2    27  0.0  1987  0.696  0.883
# 1        1        1  Control    14    2    30  0.0  2004  0.681  0.876
# 2        2        2      DCL    12    3    23  0.5  1678  0.736  1.046
# 3        3        3      DCL    12    2    28  0.5  1738  0.713  1.010
# 4        4        4      DCL    12    3    22  0.5  1698  0.701  1.034
# ..     ...      ...      ...   ...  ...   ...  ...   ...    ...    ...
# 368    368      368      DCL    16    1    28  0.5  1693  0.694  1.037
# 369    369      369      DCL    16    1    26  0.5  1688  0.675  1.040
# 370    370      370  Control    13    2    30  0.0  1319  0.801  1.331
# 371    371      371  Control    13    2    30  0.0  1327  0.796  1.323
# 372    372      372  Control    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
del alzheimer_copy["index"]
alzheimer_copy
# Out:
#      level_0    Group  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0          0  Control    14    2    27  0.0  1987  0.696  0.883
# 1          1  Control    14    2    30  0.0  2004  0.681  0.876
# 2          2      DCL    12    3    23  0.5  1678  0.736  1.046
# 3          3      DCL    12    2    28  0.5  1738  0.713  1.010
# 4          4      DCL    12    3    22  0.5  1698  0.701  1.034
# ..       ...      ...   ...  ...   ...  ...   ...    ...    ...
# 368      368      DCL    16    1    28  0.5  1693  0.694  1.037
# 369      369      DCL    16    1    26  0.5  1688  0.675  1.040
# 370      370  Control    13    2    30  0.0  1319  0.801  1.331
# 371      371  Control    13    2    30  0.0  1327  0.796  1.323
# 372      372  Control    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 9 columns]

# %%
alzheimer_edad_70= alzheimer[(alzheimer["Age"] < 14)]
print(alzheimer_edad_70)
print(alzheimer_copy)
# Out:
# Empty DataFrame
# Columns: [Group, Sexo, Age, Educ, SES, MMSE, CDR, eTIV, nWBV, ASF]
# Index: []
#      level_0    Group  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0          0  Control    14    2    27  0.0  1987  0.696  0.883
# 1          1  Control    14    2    30  0.0  2004  0.681  0.876
# 2          2      DCL    12    3    23  0.5  1678  0.736  1.046
# 3          3      DCL    12    2    28  0.5  1738  0.713  1.010
# 4          4      DCL    12    3    22  0.5  1698  0.701  1.034
# ..       ...      ...   ...  ...   ...  ...   ...    ...    ...
# 368      368      DCL    16    1    28  0.5  1693  0.694  1.037
# 369      369      DCL    16    1    26  0.5  1688  0.675  1.040
# 370      370  Control    13    2    30  0.0  1319  0.801  1.331
# 371      371  Control    13    2    30  0.0  1327  0.796  1.323
# 372      372  Control    13    2    30  0.0  1333  0.801  1.317
#
# [373 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x="Educ", y="Age", data=alzheimer, estimator=np.median)
# Out:
# <Axes: xlabel='Educ', ylabel='Age'>
